# %%
import json
import re
import requests
import scrapy
from scrapy.selector import Selector
from scrapy.http import HtmlResponse

# %%
headers = {'User-Agent': 'UNC Journo Class'}
base_url = 'https://www.metmuseum.org/art/collection/'
url = base_url + 'search#!?showOnly=withImage%7Copenaccess&offset=0&pageSize=0&sortBy=Relevance&sortOrder=asc&perPage=100&material=Oil%20paint'
resp = requests.get(url, headers=headers)

# %%
met1 = requests.get('https://www.metmuseum.org/api/collection/collectionlisting?artist=&department=&era=&geolocation=&material=Oil+paint&offset=0&pageSize=0&perPage=100&showOnly=withImage%7Copenaccess&sortBy=Relevance&sortOrder=asc',headers=headers)
body_str = met1.content.decode('utf-8')
#sel = scrapy.Selector(text=body_str)
#table = sel.css('body').xpath('string()').extract()
#table.json()
json_data = json.loads(met1.text)
with open('met1.json', 'w') as f:
    json.dump(json_data, f)
    
met2 = requests.get('https://www.metmuseum.org/api/collection/collectionlisting?artist=&department=&era=&geolocation=&material=Oil+paintings%7CPaintings&offset=100&pageSize=0&perPage=100&q=&showOnly=&sortBy=Relevance&sortOrder=asc',headers=headers)
body_str = met2.content.decode('utf-8')
json_data2 = json.loads(met2.text)
met2.json()

met3 = requests.get('https://www.metmuseum.org/api/collection/collectionlisting?artist=&department=&era=&geolocation=&material=Oil+paintings%7CPaintings&offset=200&pageSize=0&perPage=100&q=&showOnly=&sortBy=Relevance&sortOrder=asc')
body_str = met3.content.decode('utf-8')
json_data3 = json.loads(met3.text)
met3.json()

met4 = requests.get('https://www.metmuseum.org/api/collection/collectionlisting?artist=&department=&era=&geolocation=&material=Oil+paintings%7CPaintings&offset=300&pageSize=0&perPage=100&q=&showOnly=&sortBy=Relevance&sortOrder=asc')
body_str = met4.content.decode('utf-8')
json_data4 = json.loads(met4.text)
met4.json()

met5 = requests.get('https://www.metmuseum.org/api/collection/collectionlisting?artist=&department=&era=&geolocation=&material=Oil+paintings%7CPaintings&offset=400&pageSize=0&perPage=100&q=&showOnly=&sortBy=Relevance&sortOrder=asc')
body_str = met5.content.decode('utf-8')
json_data5 = json.loads(met5.text)
met5.json()
# Out:
# {'correctedQuery': None,
#  'facets': [{'facets': None,
#    'filterGroupId': None,
#    'filterGroupItems': None,
#    'filterGroupLabel': None,
#    'filterGroupName': None,
#    'filterGroupType': None,
#    'id': 'artist',
#    'label': 'Artist / Culture',
#    'name': None,
#    'values': [{'count': 14,
#      'hidden': False,
#      'id': 'Albers, Josef$Josef Albers',
#      'label': 'Josef Albers',
#      'name': 'Albers, Josef',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Alexander, John White$John White Alexander',
#      'label': 'John White Alexander',
#      'name': 'Alexander, John White',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'André, Albert$Albert André',
#      'label': 'Albert André',
#      'name': 'André, Albert',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'Avery, Milton$Milton Avery',
#      'label': 'Milton Avery',
#      'name': 'Avery, Milton',
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Balthus (Balthasar Klossowski)$Balthus (Balthasar Klossowski)',
#      'label': 'Balthus (Balthasar Klossowski)',
#      'name': 'Balthus (Balthasar Klossowski)',
#      'orderId': 0,
#      'selected': False},
#     {'count': 11,
#      'hidden': False,
#      'id': 'Bellows, George$George Bellows',
#      'label': 'George Bellows',
#      'name': 'Bellows, George',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Benton, Thomas Hart$Thomas Hart Benton',
#      'label': 'Thomas Hart Benton',
#      'name': 'Benton, Thomas Hart',
#      'orderId': 0,
#      'selected': False},
#     {'count': 10,
#      'hidden': False,
#      'id': 'Bierstadt, Albert$Albert Bierstadt',
#      'label': 'Albert Bierstadt',
#      'name': 'Bierstadt, Albert',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'Blakelock, Ralph Albert$Ralph Albert Blakelock',
#      'label': 'Ralph Albert Blakelock',
#      'name': 'Blakelock, Ralph Albert',
#      'orderId': 0,
#      'selected': False},
#     {'count': 23,
#      'hidden': False,
#      'id': 'Bonnard, Pierre$Pierre Bonnard',
#      'label': 'Pierre Bonnard',
#      'name': 'Bonnard, Pierre',
#      'orderId': 0,
#      'selected': False},
#     {'count': 15,
#      'hidden': False,
#      'id': 'Braque, Georges$Georges Braque',
#      'label': 'Georges Braque',
#      'name': 'Braque, Georges',
#      'orderId': 0,
#      'selected': False},
#     {'count': 5,
#      'hidden': False,
#      'id': 'Brown, Frederick J$Frederick J. Brown',
#      'label': 'Frederick J. Brown',
#      'name': 'Brown, Frederick J',
#      'orderId': 0,
#      'selected': False},
#     {'count': 11,
#      'hidden': False,
#      'id': 'Cassatt, Mary$Mary Cassatt',
#      'label': 'Mary Cassatt',
#      'name': 'Cassatt, Mary',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'Chagall, Marc$Marc Chagall',
#      'label': 'Marc Chagall',
#      'name': 'Chagall, Marc',
#      'orderId': 0,
#      'selected': False},
#     {'count': 27,
#      'hidden': False,
#      'id': 'Chappel, William P.$William P. Chappel',
#      'label': 'William P. Chappel',
#      'name': 'Chappel, William P.',
#      'orderId': 0,
#      'selected': False},
#     {'count': 13,
#      'hidden': False,
#      'id': 'Chase, William Merritt$William Merritt Chase',
#      'label': 'William Merritt Chase',
#      'name': 'Chase, William Merritt',
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Cole, Thomas$Thomas Cole',
#      'label': 'Thomas Cole',
#      'name': 'Cole, Thomas',
#      'orderId': 0,
#      'selected': False},
#     {'count': 5,
#      'hidden': False,
#      'id': 'Colman, Samuel$Samuel Colman',
#      'label': 'Samuel Colman',
#      'name': 'Colman, Samuel',
#      'orderId': 0,
#      'selected': False},
#     {'count': 17,
#      'hidden': False,
#      'id': 'Copley, John Singleton$John Singleton Copley',
#      'label': 'John Singleton Copley',
#      'name': 'Copley, John Singleton',
#      'orderId': 0,
#      'selected': False},
#     {'count': 5,
#      'hidden': False,
#      'id': 'Cropsey, Jasper Francis$Jasper Francis Cropsey',
#      'label': 'Jasper Francis Cropsey',
#      'name': 'Cropsey, Jasper Francis',
#      'orderId': 0,
#      'selected': False},
#     {'count': 5,
#      'hidden': False,
#      'id': 'Dalí, Salvador$Salvador Dalí',
#      'label': 'Salvador Dalí',
#      'name': 'Dalí, Salvador',
#      'orderId': 0,
#      'selected': False},
#     {'count': 9,
#      'hidden': False,
#      'id': 'Davies, Arthur .$Arthur . Davies',
#      'label': 'Arthur . Davies',
#      'name': 'Davies, Arthur .',
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Davis, Stuart$Stuart Davis',
#      'label': 'Stuart Davis',
#      'name': 'Davis, Stuart',
#      'orderId': 0,
#      'selected': False},
#     {'count': 14,
#      'hidden': False,
#      'id': 'De Kooning, Willem$Willem de Kooning',
#      'label': 'Willem de Kooning',
#      'name': 'De Kooning, Willem',
#      'orderId': 0,
#      'selected': False},
#     {'count': 14,
#      'hidden': False,
#      'id': 'Derain, André$André Derain',
#      'label': 'André Derain',
#      'name': 'Derain, André',
#      'orderId': 0,
#      'selected': False},
#     {'count': 9,
#      'hidden': False,
#      'id': "d'Espagnat Georges$Georges d'Espagnat",
#      'label': "Georges d'Espagnat",
#      'name': "d'Espagnat Georges",
#      'orderId': 0,
#      'selected': False},
#     {'count': 5,
#      'hidden': False,
#      'id': 'Dickinson, Edwin$Edwin Dickinson',
#      'label': 'Edwin Dickinson',
#      'name': 'Dickinson, Edwin',
#      'orderId': 0,
#      'selected': False},
#     {'count': 13,
#      'hidden': False,
#      'id': 'Dine, Jim$Jim Dine',
#      'label': 'Jim Dine',
#      'name': 'Dine, Jim',
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Dove, Arthur$Arthur Dove',
#      'label': 'Arthur Dove',
#      'name': 'Dove, Arthur',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'Dubuffet, Jean$Jean Dubuffet',
#      'label': 'Jean Dubuffet',
#      'name': 'Dubuffet, Jean',
#      'orderId': 0,
#      'selected': False},
#     {'count': 12,
#      'hidden': False,
#      'id': 'Durand, Asher Brown$Asher Brown Durand',
#      'label': 'Asher Brown Durand',
#      'name': 'Durand, Asher Brown',
#      'orderId': 0,
#      'selected': False},
#     {'count': 11,
#      'hidden': False,
#      'id': 'Eakins, Thomas$Thomas Eakins',
#      'label': 'Thomas Eakins',
#      'name': 'Eakins, Thomas',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Earl, Ralph$Ralph Earl',
#      'label': 'Ralph Earl',
#      'name': 'Earl, Ralph',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Edzard, Dietz$Dietz Edzard',
#      'label': 'Dietz Edzard',
#      'name': 'Edzard, Dietz',
#      'orderId': 0,
#      'selected': False},
#     {'count': 11,
#      'hidden': False,
#      'id': 'Eilshemius, Louis Michel$Louis Michel Eilshemius',
#      'label': 'Louis Michel Eilshemius',
#      'name': 'Eilshemius, Louis Michel',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Elliott, Charles Loring$Charles Loring Elliott',
#      'label': 'Charles Loring Elliott',
#      'name': 'Elliott, Charles Loring',
#      'orderId': 0,
#      'selected': False},
#     {'count': 5,
#      'hidden': False,
#      'id': 'Enríquez, Nicolás$Nicolás Enríquez',
#      'label': 'Nicolás Enríquez',
#      'name': 'Enríquez, Nicolás',
#      'orderId': 0,
#      'selected': False},
#     {'count': 9,
#      'hidden': False,
#      'id': 'Fagnani, Joseph$Joseph Fagnani',
#      'label': 'Joseph Fagnani',
#      'name': 'Fagnani, Joseph',
#      'orderId': 0,
#      'selected': False},
#     {'count': 5,
#      'hidden': False,
#      'id': 'Gottlieb, Adolph$Adolph Gottlieb',
#      'label': 'Adolph Gottlieb',
#      'name': 'Gottlieb, Adolph',
#      'orderId': 0,
#      'selected': False},
#     {'count': 5,
#      'hidden': False,
#      'id': 'Gris, Juan$Juan Gris',
#      'label': 'Juan Gris',
#      'name': 'Gris, Juan',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'Guston, Philip$Philip Guston',
#      'label': 'Philip Guston',
#      'name': 'Guston, Philip',
#      'orderId': 0,
#      'selected': False},
#     {'count': 16,
#      'hidden': False,
#      'id': 'Hartley, Marsden$Marsden Hartley',
#      'label': 'Marsden Hartley',
#      'name': 'Hartley, Marsden',
#      'orderId': 0,
#      'selected': False},
#     {'count': 12,
#      'hidden': False,
#      'id': 'Hassam, Childe$Childe Hassam',
#      'label': 'Childe Hassam',
#      'name': 'Hassam, Childe',
#      'orderId': 0,
#      'selected': False},
#     {'count': 9,
#      'hidden': False,
#      'id': 'Helion, Jean$Jean Hélion',
#      'label': 'Jean Hélion',
#      'name': 'Helion, Jean',
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Henri, Robert$Robert Henri',
#      'label': 'Robert Henri',
#      'name': 'Henri, Robert',
#      'orderId': 0,
#      'selected': False},
#     {'count': 14,
#      'hidden': False,
#      'id': 'Hofmann, Hans$Hans Hofmann',
#      'label': 'Hans Hofmann',
#      'name': 'Hofmann, Hans',
#      'orderId': 0,
#      'selected': False},
#     {'count': 19,
#      'hidden': False,
#      'id': 'Homer, Winslow$Winslow Homer',
#      'label': 'Winslow Homer',
#      'name': 'Homer, Winslow',
#      'orderId': 0,
#      'selected': False},
#     {'count': 9,
#      'hidden': False,
#      'id': 'Hunt, William Morris$William Morris Hunt',
#      'label': 'William Morris Hunt',
#      'name': 'Hunt, William Morris',
#      'orderId': 0,
#      'selected': False},
#     {'count': 11,
#      'hidden': False,
#      'id': 'Huntington, Daniel$Daniel Huntington',
#      'label': 'Daniel Huntington',
#      'name': 'Huntington, Daniel',
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Inman, Henry$Henry Inman',
#      'label': 'Henry Inman',
#      'name': 'Inman, Henry',
#      'orderId': 0,
#      'selected': False},
#     {'count': 10,
#      'hidden': False,
#      'id': 'Inness, George$George Inness',
#      'label': 'George Inness',
#      'name': 'Inness, George',
#      'orderId': 0,
#      'selected': False},
#     {'count': 9,
#      'hidden': False,
#      'id': 'Jarvis, John Wesley$John Wesley Jarvis',
#      'label': 'John Wesley Jarvis',
#      'name': 'Jarvis, John Wesley',
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Jewett, William$William Jewett',
#      'label': 'William Jewett',
#      'name': 'Jewett, William',
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Johnson, Eastman$Eastman Johnson',
#      'label': 'Eastman Johnson',
#      'name': 'Johnson, Eastman',
#      'orderId': 0,
#      'selected': False},
#     {'count': 9,
#      'hidden': False,
#      'id': 'Katz, Alex$Alex Katz',
#      'label': 'Alex Katz',
#      'name': 'Katz, Alex',
#      'orderId': 0,
#      'selected': False},
#     {'count': 22,
#      'hidden': False,
#      'id': 'Kensett, John Frederick$John Frederick Kensett',
#      'label': 'John Frederick Kensett',
#      'name': 'Kensett, John Frederick',
#      'orderId': 0,
#      'selected': False},
#     {'count': 16,
#      'hidden': False,
#      'id': 'Klee, Paul$Paul Klee',
#      'label': 'Paul Klee',
#      'name': 'Klee, Paul',
#      'orderId': 0,
#      'selected': False},
#     {'count': 13,
#      'hidden': False,
#      'id': 'Kline, Franz$Franz Kline',
#      'label': 'Franz Kline',
#      'name': 'Kline, Franz',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Krasner, Lee$Lee Krasner',
#      'label': 'Lee Krasner',
#      'name': 'Krasner, Lee',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'Kuhn, Walt$Walt Kuhn',
#      'label': 'Walt Kuhn',
#      'name': 'Kuhn, Walt',
#      'orderId': 0,
#      'selected': False},
#     {'count': 12,
#      'hidden': False,
#      'id': 'Léger, Fernand$Fernand Léger',
#      'label': 'Fernand Léger',
#      'name': 'Léger, Fernand',
#      'orderId': 0,
#      'selected': False},
#     {'count': 12,
#      'hidden': False,
#      'id': 'MacIver, Loren$Loren MacIver',
#      'label': 'Loren MacIver',
#      'name': 'MacIver, Loren',
#      'orderId': 0,
#      'selected': False},
#     {'count': 23,
#      'hidden': False,
#      'id': 'Matisse, Henri$Henri Matisse',
#      'label': 'Henri Matisse',
#      'name': 'Matisse, Henri',
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Meyer, Melissa$Melissa Meyer',
#      'label': 'Melissa Meyer',
#      'name': 'Meyer, Melissa',
#      'orderId': 0,
#      'selected': False},
#     {'count': 11,
#      'hidden': False,
#      'id': 'Miró, Joan$Joan Miró',
#      'label': 'Joan Miró',
#      'name': 'Miró, Joan',
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Modigliani, Amedeo$Amedeo Modigliani',
#      'label': 'Amedeo Modigliani',
#      'name': 'Modigliani, Amedeo',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'Mount, William Sidney$William Sidney Mount',
#      'label': 'William Sidney Mount',
#      'name': 'Mount, William Sidney',
#      'orderId': 0,
#      'selected': False},
#     {'count': 16,
#      'hidden': False,
#      'id': "O'Keeffe, Georgia$Georgia O'Keeffe",
#      'label': "Georgia O'Keeffe",
#      'name': "O'Keeffe, Georgia",
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Peale, Charles Willson$Charles Willson Peale',
#      'label': 'Charles Willson Peale',
#      'name': 'Peale, Charles Willson',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Peale, Rembrandt$Rembrandt Peale',
#      'label': 'Rembrandt Peale',
#      'name': 'Peale, Rembrandt',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Pearlstein, Philip$Philip Pearlstein',
#      'label': 'Philip Pearlstein',
#      'name': 'Pearlstein, Philip',
#      'orderId': 0,
#      'selected': False},
#     {'count': 35,
#      'hidden': False,
#      'id': 'Picasso, Pablo$Pablo Picasso',
#      'label': 'Pablo Picasso',
#      'name': 'Picasso, Pablo',
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Pippin, Horace$Horace Pippin',
#      'label': 'Horace Pippin',
#      'name': 'Pippin, Horace',
#      'orderId': 0,
#      'selected': False},
#     {'count': 20,
#      'hidden': False,
#      'id': 'Porter, Fairfield$Fairfield Porter',
#      'label': 'Fairfield Porter',
#      'name': 'Porter, Fairfield',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'Prendergast, Maurice Brazil$Maurice Brazil Prendergast',
#      'label': 'Maurice Brazil Prendergast',
#      'name': 'Prendergast, Maurice Brazil',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Rothko, Mark$Mark Rothko',
#      'label': 'Mark Rothko',
#      'name': 'Rothko, Mark',
#      'orderId': 0,
#      'selected': False},
#     {'count': 9,
#      'hidden': False,
#      'id': 'Rouault, Georges$Georges Rouault',
#      'label': 'Georges Rouault',
#      'name': 'Rouault, Georges',
#      'orderId': 0,
#      'selected': False},
#     {'count': 11,
#      'hidden': False,
#      'id': 'Ryder, Albert Pinkham$Albert Pinkham Ryder',
#      'label': 'Albert Pinkham Ryder',
#      'name': 'Ryder, Albert Pinkham',
#      'orderId': 0,
#      'selected': False},
#     {'count': 40,
#      'hidden': False,
#      'id': 'Sargent, John Singer$John Singer Sargent',
#      'label': 'John Singer Sargent',
#      'name': 'Sargent, John Singer',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'Soutine, Chaim$Chaim Soutine',
#      'label': 'Chaim Soutine',
#      'name': 'Soutine, Chaim',
#      'orderId': 0,
#      'selected': False},
#     {'count': 10,
#      'hidden': False,
#      'id': 'Soyer, Raphael$Raphael Soyer',
#      'label': 'Raphael Soyer',
#      'name': 'Soyer, Raphael',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Speicher, Eugene$Eugene Speicher',
#      'label': 'Eugene Speicher',
#      'name': 'Speicher, Eugene',
#      'orderId': 0,
#      'selected': False},
#     {'count': 12,
#      'hidden': False,
#      'id': 'Still, Clyfford$Clyfford Still',
#      'label': 'Clyfford Still',
#      'name': 'Still, Clyfford',
#      'orderId': 0,
#      'selected': False},
#     {'count': 30,
#      'hidden': False,
#      'id': 'Stuart, Gilbert$Gilbert Stuart',
#      'label': 'Gilbert Stuart',
#      'name': 'Stuart, Gilbert',
#      'orderId': 0,
#      'selected': False},
#     {'count': 16,
#      'hidden': False,
#      'id': 'Sully, Thomas$Thomas Sully',
#      'label': 'Thomas Sully',
#      'name': 'Sully, Thomas',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Tanguy, Yves$Yves Tanguy',
#      'label': 'Yves Tanguy',
#      'name': 'Tanguy, Yves',
#      'orderId': 0,
#      'selected': False},
#     {'count': 10,
#      'hidden': False,
#      'id': 'Trumbull, John$John Trumbull',
#      'label': 'John Trumbull',
#      'name': 'Trumbull, John',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Utrillo, Maurice$Maurice Utrillo',
#      'label': 'Maurice Utrillo',
#      'name': 'Utrillo, Maurice',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Vallotton, Félix$Félix Vallotton',
#      'label': 'Félix Vallotton',
#      'name': 'Vallotton, Félix',
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Vanderlyn, John$John Vanderlyn',
#      'label': 'John Vanderlyn',
#      'name': 'Vanderlyn, John',
#      'orderId': 0,
#      'selected': False},
#     {'count': 17,
#      'hidden': False,
#      'id': 'Vedder, Elihu$Elihu Vedder',
#      'label': 'Elihu Vedder',
#      'name': 'Vedder, Elihu',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Vlaminck, Maurice de$Maurice de Vlaminck',
#      'label': 'Maurice de Vlaminck',
#      'name': 'Vlaminck, Maurice de',
#      'orderId': 0,
#      'selected': False},
#     {'count': 12,
#      'hidden': False,
#      'id': 'Vuillard, Édouard$Édouard Vuillard',
#      'label': 'Édouard Vuillard',
#      'name': 'Vuillard, Édouard',
#      'orderId': 0,
#      'selected': False},
#     {'count': 15,
#      'hidden': False,
#      'id': 'Waldo, Samuel Lovett$Samuel Lovett Waldo',
#      'label': 'Samuel Lovett Waldo',
#      'name': 'Waldo, Samuel Lovett',
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Weber, Max$Max Weber',
#      'label': 'Max Weber',
#      'name': 'Weber, Max',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Weir, Julian Alden$Julian Alden Weir',
#      'label': 'Julian Alden Weir',
#      'name': 'Weir, Julian Alden',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'West, Benjamin$Benjamin West',
#      'label': 'Benjamin West',
#      'name': 'West, Benjamin',
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Whistler, James McNeill$James McNeill Whistler',
#      'label': 'James McNeill Whistler',
#      'name': 'Whistler, James McNeill',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'Wollaston, John$John Wollaston',
#      'label': 'John Wollaston',
#      'name': 'Wollaston, John',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Wyant, Alexander H.$Alexander H. Wyant',
#      'label': 'Alexander H. Wyant',
#      'name': 'Wyant, Alexander H.',
#      'orderId': 0,
#      'selected': False}]},
#   {'facets': None,
#    'filterGroupId': None,
#    'filterGroupItems': None,
#    'filterGroupLabel': None,
#    'filterGroupName': None,
#    'filterGroupType': None,
#    'id': 'material',
#    'label': 'Object Type / Material',
#    'name': None,
#    'values': [{'count': 31,
#      'hidden': False,
#      'id': 'Acrylic',
#      'label': 'Acrylic',
#      'name': 'Acrylic',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Acrylic paint',
#      'label': 'Acrylic paint',
#      'name': 'Acrylic paint',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Adhesive tape',
#      'label': 'Adhesive tape',
#      'name': 'Adhesive tape',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Alkyd resin',
#      'label': 'Alkyd resin',
#      'name': 'Alkyd resin',
#      'orderId': 0,
#      'selected': False},
#     {'count': 12,
#      'hidden': False,
#      'id': 'Aluminum',
#      'label': 'Aluminum',
#      'name': 'Aluminum',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Aluminum paint',
#      'label': 'Aluminum paint',
#      'name': 'Aluminum paint',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Asphaltum',
#      'label': 'Asphaltum',
#      'name': 'Asphaltum',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Barbed wire',
#      'label': 'Barbed wire',
#      'name': 'Barbed wire',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Beech',
#      'label': 'Beech',
#      'name': 'Beech',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Boxes',
#      'label': 'Boxes',
#      'name': 'Boxes',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Bronze',
#      'label': 'Bronze',
#      'name': 'Bronze',
#      'orderId': 0,
#      'selected': False},
#     {'count': 4,
#      'hidden': False,
#      'id': 'Burlap',
#      'label': 'Burlap',
#      'name': 'Burlap',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2345,
#      'hidden': False,
#      'id': 'Canvas',
#      'label': 'Canvas',
#      'name': 'Canvas',
#      'orderId': 0,
#      'selected': False},
#     {'count': 4,
#      'hidden': False,
#      'id': 'Canvas board',
#      'label': 'Canvas board',
#      'name': 'Canvas board',
#      'orderId': 0,
#      'selected': False},
#     {'count': 78,
#      'hidden': False,
#      'id': 'Cardboard',
#      'label': 'Cardboard',
#      'name': 'Cardboard',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Casein',
#      'label': 'Casein',
#      'name': 'Casein',
#      'orderId': 0,
#      'selected': False},
#     {'count': 4,
#      'hidden': False,
#      'id': 'Ceramics',
#      'label': 'Ceramics',
#      'name': 'Ceramics',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'Chalk',
#      'label': 'Chalk',
#      'name': 'Chalk',
#      'orderId': 0,
#      'selected': False},
#     {'count': 52,
#      'hidden': False,
#      'id': 'Charcoal',
#      'label': 'Charcoal',
#      'name': 'Charcoal',
#      'orderId': 0,
#      'selected': False},
#     {'count': 12,
#      'hidden': False,
#      'id': 'Cloth',
#      'label': 'Cloth',
#      'name': 'Cloth',
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Collages',
#      'label': 'Collages',
#      'name': 'Collages',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Colored pencils',
#      'label': 'Colored pencils',
#      'name': 'Colored pencils',
#      'orderId': 0,
#      'selected': False},
#     {'count': 16,
#      'hidden': False,
#      'id': 'Copper',
#      'label': 'Copper',
#      'name': 'Copper',
#      'orderId': 0,
#      'selected': False},
#     {'count': 5,
#      'hidden': False,
#      'id': 'Copper alloy',
#      'label': 'Copper alloy',
#      'name': 'Copper alloy',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Cord',
#      'label': 'Cord',
#      'name': 'Cord',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Costume',
#      'label': 'Costume',
#      'name': 'Costume',
#      'orderId': 0,
#      'selected': False},
#     {'count': 17,
#      'hidden': False,
#      'id': 'Crayons',
#      'label': 'Crayons',
#      'name': 'Crayons',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Cutouts',
#      'label': 'Cutouts',
#      'name': 'Cutouts',
#      'orderId': 0,
#      'selected': False},
#     {'count': 161,
#      'hidden': False,
#      'id': 'Drawings',
#      'label': 'Drawings',
#      'name': 'Drawings',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Ebony',
#      'label': 'Ebony',
#      'name': 'Ebony',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Egg tempera',
#      'label': 'Egg tempera',
#      'name': 'Egg tempera',
#      'orderId': 0,
#      'selected': False},
#     {'count': 24,
#      'hidden': False,
#      'id': 'Enamel paint',
#      'label': 'Enamel paint',
#      'name': 'Enamel paint',
#      'orderId': 0,
#      'selected': False},
#     {'count': 4,
#      'hidden': False,
#      'id': 'Encaustic painting',
#      'label': 'Encaustic painting',
#      'name': 'Encaustic painting',
#      'orderId': 0,
#      'selected': False},
#     {'count': 5,
#      'hidden': False,
#      'id': 'Fiberboard',
#      'label': 'Fiberboard',
#      'name': 'Fiberboard',
#      'orderId': 0,
#      'selected': False},
#     {'count': 12,
#      'hidden': False,
#      'id': 'Frames',
#      'label': 'Frames',
#      'name': 'Frames',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Friezes',
#      'label': 'Friezes',
#      'name': 'Friezes',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'Gesso',
#      'label': 'Gesso',
#      'name': 'Gesso',
#      'orderId': 0,
#      'selected': False},
#     {'count': 4,
#      'hidden': False,
#      'id': 'Gilt',
#      'label': 'Gilt',
#      'name': 'Gilt',
#      'orderId': 0,
#      'selected': False},
#     {'count': 9,
#      'hidden': False,
#      'id': 'Glass',
#      'label': 'Glass',
#      'name': 'Glass',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Glaze',
#      'label': 'Glaze',
#      'name': 'Glaze',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Glazing',
#      'label': 'Glazing',
#      'name': 'Glazing',
#      'orderId': 0,
#      'selected': False},
#     {'count': 19,
#      'hidden': False,
#      'id': 'Gold',
#      'label': 'Gold',
#      'name': 'Gold',
#      'orderId': 0,
#      'selected': False},
#     {'count': 9,
#      'hidden': False,
#      'id': 'Gold leaf',
#      'label': 'Gold leaf',
#      'name': 'Gold leaf',
#      'orderId': 0,
#      'selected': False},
#     {'count': 16,
#      'hidden': False,
#      'id': 'Gouaches',
#      'label': 'Gouaches',
#      'name': 'Gouaches',
#      'orderId': 0,
#      'selected': False},
#     {'count': 67,
#      'hidden': False,
#      'id': 'Graphite',
#      'label': 'Graphite',
#      'name': 'Graphite',
#      'orderId': 0,
#      'selected': False},
#     {'count': 5,
#      'hidden': False,
#      'id': 'Gypsum',
#      'label': 'Gypsum',
#      'name': 'Gypsum',
#      'orderId': 0,
#      'selected': False},
#     {'count': 34,
#      'hidden': False,
#      'id': 'Ink',
#      'label': 'Ink',
#      'name': 'Ink',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Iron alloy',
#      'label': 'Iron alloy',
#      'name': 'Iron alloy',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'Iron and iron alloy',
#      'label': 'Iron and iron alloy',
#      'name': 'Iron and iron alloy',
#      'orderId': 0,
#      'selected': False},
#     {'count': 5,
#      'hidden': False,
#      'id': 'Lead',
#      'label': 'Lead',
#      'name': 'Lead',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Leather',
#      'label': 'Leather',
#      'name': 'Leather',
#      'orderId': 0,
#      'selected': False},
#     {'count': 17,
#      'hidden': False,
#      'id': 'Linen',
#      'label': 'Linen',
#      'name': 'Linen',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Lithography',
#      'label': 'Lithography',
#      'name': 'Lithography',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Mahogany',
#      'label': 'Mahogany',
#      'name': 'Mahogany',
#      'orderId': 0,
#      'selected': False},
#     {'count': 5,
#      'hidden': False,
#      'id': 'Markers',
#      'label': 'Markers',
#      'name': 'Markers',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Masking tape',
#      'label': 'Masking tape',
#      'name': 'Masking tape',
#      'orderId': 0,
#      'selected': False},
#     {'count': 117,
#      'hidden': False,
#      'id': 'Masonite',
#      'label': 'Masonite',
#      'name': 'Masonite',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Mats',
#      'label': 'Mats',
#      'name': 'Mats',
#      'orderId': 0,
#      'selected': False},
#     {'count': 68,
#      'hidden': False,
#      'id': 'Metal',
#      'label': 'Metal',
#      'name': 'Metal',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Metallic paint',
#      'label': 'Metallic paint',
#      'name': 'Metallic paint',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Metalwork',
#      'label': 'Metalwork',
#      'name': 'Metalwork',
#      'orderId': 0,
#      'selected': False},
#     {'count': 4,
#      'hidden': False,
#      'id': 'Millboard',
#      'label': 'Millboard',
#      'name': 'Millboard',
#      'orderId': 0,
#      'selected': False},
#     {'count': 11,
#      'hidden': False,
#      'id': 'Miniatures',
#      'label': 'Miniatures',
#      'name': 'Miniatures',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Mixed media',
#      'label': 'Mixed media',
#      'name': 'Mixed media',
#      'orderId': 0,
#      'selected': False},
#     {'count': 5,
#      'hidden': False,
#      'id': 'Murals',
#      'label': 'Murals',
#      'name': 'Murals',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Nails',
#      'label': 'Nails',
#      'name': 'Nails',
#      'orderId': 0,
#      'selected': False},
#     {'count': 17,
#      'hidden': False,
#      'id': 'Oak',
#      'label': 'Oak',
#      'name': 'Oak',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3023,
#      'hidden': False,
#      'id': 'Oil paintings',
#      'label': 'Oil paintings',
#      'name': 'Oil paintings',
#      'orderId': 0,
#      'selected': True},
#     {'count': 9,
#      'hidden': False,
#      'id': 'Painting',
#      'label': 'Painting',
#      'name': 'Painting',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3023,
#      'hidden': False,
#      'id': 'Paintings',
#      'label': 'Paintings',
#      'name': 'Paintings',
#      'orderId': 0,
#      'selected': True},
#     {'count': 62,
#      'hidden': False,
#      'id': 'Panels',
#      'label': 'Panels',
#      'name': 'Panels',
#      'orderId': 0,
#      'selected': False},
#     {'count': 258,
#      'hidden': False,
#      'id': 'Paper',
#      'label': 'Paper',
#      'name': 'Paper',
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Papers',
#      'label': 'Papers',
#      'name': 'Papers',
#      'orderId': 0,
#      'selected': False},
#     {'count': 42,
#      'hidden': False,
#      'id': 'Pastels',
#      'label': 'Pastels',
#      'name': 'Pastels',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Pen',
#      'label': 'Pen',
#      'name': 'Pen',
#      'orderId': 0,
#      'selected': False},
#     {'count': 8,
#      'hidden': False,
#      'id': 'Pencil',
#      'label': 'Pencil',
#      'name': 'Pencil',
#      'orderId': 0,
#      'selected': False},
#     {'count': 5,
#      'hidden': False,
#      'id': 'Photographs',
#      'label': 'Photographs',
#      'name': 'Photographs',
#      'orderId': 0,
#      'selected': False},
#     {'count': 9,
#      'hidden': False,
#      'id': 'Plaster',
#      'label': 'Plaster',
#      'name': 'Plaster',
#      'orderId': 0,
#      'selected': False},
#     {'count': 39,
#      'hidden': False,
#      'id': 'Plastic',
#      'label': 'Plastic',
#      'name': 'Plastic',
#      'orderId': 0,
#      'selected': False},
#     {'count': 10,
#      'hidden': False,
#      'id': 'Plywood',
#      'label': 'Plywood',
#      'name': 'Plywood',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Pressboard',
#      'label': 'Pressboard',
#      'name': 'Pressboard',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'Printing',
#      'label': 'Printing',
#      'name': 'Printing',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Prints',
#      'label': 'Prints',
#      'name': 'Prints',
#      'orderId': 0,
#      'selected': False},
#     {'count': 12,
#      'hidden': False,
#      'id': 'Resin',
#      'label': 'Resin',
#      'name': 'Resin',
#      'orderId': 0,
#      'selected': False},
#     {'count': 14,
#      'hidden': False,
#      'id': 'Sculpture',
#      'label': 'Sculpture',
#      'name': 'Sculpture',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Shellac',
#      'label': 'Shellac',
#      'name': 'Shellac',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Silver',
#      'label': 'Silver',
#      'name': 'Silver',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Softwood',
#      'label': 'Softwood',
#      'name': 'Softwood',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Steel',
#      'label': 'Steel',
#      'name': 'Steel',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Synthetic',
#      'label': 'Synthetic',
#      'name': 'Synthetic',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Tar',
#      'label': 'Tar',
#      'name': 'Tar',
#      'orderId': 0,
#      'selected': False},
#     {'count': 22,
#      'hidden': False,
#      'id': 'Tempera',
#      'label': 'Tempera',
#      'name': 'Tempera',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Tin',
#      'label': 'Tin',
#      'name': 'Tin',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Triptychs',
#      'label': 'Triptychs',
#      'name': 'Triptychs',
#      'orderId': 0,
#      'selected': False},
#     {'count': 17,
#      'hidden': False,
#      'id': 'Watercolors',
#      'label': 'Watercolors',
#      'name': 'Watercolors',
#      'orderId': 0,
#      'selected': False},
#     {'count': 23,
#      'hidden': False,
#      'id': 'Wax',
#      'label': 'Wax',
#      'name': 'Wax',
#      'orderId': 0,
#      'selected': False},
#     {'count': 4,
#      'hidden': False,
#      'id': 'Wax crayons',
#      'label': 'Wax crayons',
#      'name': 'Wax crayons',
#      'orderId': 0,
#      'selected': False},
#     {'count': 4,
#      'hidden': False,
#      'id': 'Wire',
#      'label': 'Wire',
#      'name': 'Wire',
#      'orderId': 0,
#      'selected': False},
#     {'count': 43,
#      'hidden': False,
#      'id': 'Wood',
#      'label': 'Wood',
#      'name': 'Wood',
#      'orderId': 0,
#      'selected': False},
#     {'count': 4,
#      'hidden': False,
#      'id': 'Wove paper',
#      'label': 'Wove paper',
#      'name': 'Wove paper',
#      'orderId': 0,
#      'selected': False}]},
#   {'facets': None,
#    'filterGroupId': None,
#    'filterGroupItems': None,
#    'filterGroupLabel': None,
#    'filterGroupName': None,
#    'filterGroupType': None,
#    'id': 'geolocation',
#    'label': 'Geographic Location',
#    'name': None,
#    'values': [{'count': 1,
#      'hidden': False,
#      'id': 'Africa',
#      'label': 'Africa',
#      'name': 'Africa',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Argentina',
#      'label': 'Argentina',
#      'name': 'Argentina',
#      'orderId': 0,
#      'selected': False},
#     {'count': 21,
#      'hidden': False,
#      'id': 'Asia',
#      'label': 'Asia',
#      'name': 'Asia',
#      'orderId': 0,
#      'selected': False},
#     {'count': 17,
#      'hidden': False,
#      'id': 'Australia',
#      'label': 'Australia',
#      'name': 'Australia',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Austria',
#      'label': 'Austria',
#      'name': 'Austria',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Baltimore',
#      'label': 'Baltimore',
#      'name': 'Baltimore',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Bavaria',
#      'label': 'Bavaria',
#      'name': 'Bavaria',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Belgium',
#      'label': 'Belgium',
#      'name': 'Belgium',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Boston',
#      'label': 'Boston',
#      'name': 'Boston',
#      'orderId': 0,
#      'selected': False},
#     {'count': 6,
#      'hidden': False,
#      'id': 'Brazil',
#      'label': 'Brazil',
#      'name': 'Brazil',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'California',
#      'label': 'California',
#      'name': 'California',
#      'orderId': 0,
#      'selected': False},
#     {'count': 4,
#      'hidden': False,
#      'id': 'Canada',
#      'label': 'Canada',
#      'name': 'Canada',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Chile',
#      'label': 'Chile',
#      'name': 'Chile',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Colombia',
#      'label': 'Colombia',
#      'name': 'Colombia',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Connecticut',
#      'label': 'Connecticut',
#      'name': 'Connecticut',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Cornish',
#      'label': 'Cornish',
#      'name': 'Cornish',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Cuba',
#      'label': 'Cuba',
#      'name': 'Cuba',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Cuzco',
#      'label': 'Cuzco',
#      'name': 'Cuzco',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Czech Republic',
#      'label': 'Czech Republic',
#      'name': 'Czech Republic',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Czechoslovakia',
#      'label': 'Czechoslovakia',
#      'name': 'Czechoslovakia',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Denmark',
#      'label': 'Denmark',
#      'name': 'Denmark',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Dubois',
#      'label': 'Dubois',
#      'name': 'Dubois',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Egypt',
#      'label': 'Egypt',
#      'name': 'Egypt',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'England',
#      'label': 'England',
#      'name': 'England',
#      'orderId': 0,
#      'selected': False},
#     {'count': 608,
#      'hidden': False,
#      'id': 'Europe',
#      'label': 'Europe',
#      'name': 'Europe',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Flanders',
#      'label': 'Flanders',
#      'name': 'Flanders',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Fort Laramie',
#      'label': 'Fort Laramie',
#      'name': 'Fort Laramie',
#      'orderId': 0,
#      'selected': False},
#     {'count': 291,
#      'hidden': False,
#      'id': 'France',
#      'label': 'France',
#      'name': 'France',
#      'orderId': 0,
#      'selected': False},
#     {'count': 47,
#      'hidden': False,
#      'id': 'Germany',
#      'label': 'Germany',
#      'name': 'Germany',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Goshen',
#      'label': 'Goshen',
#      'name': 'Goshen',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Greece',
#      'label': 'Greece',
#      'name': 'Greece',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Hartford',
#      'label': 'Hartford',
#      'name': 'Hartford',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Hungary',
#      'label': 'Hungary',
#      'name': 'Hungary',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Indiana',
#      'label': 'Indiana',
#      'name': 'Indiana',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Israel',
#      'label': 'Israel',
#      'name': 'Israel',
#      'orderId': 0,
#      'selected': False},
#     {'count': 36,
#      'hidden': False,
#      'id': 'Italy',
#      'label': 'Italy',
#      'name': 'Italy',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Japan',
#      'label': 'Japan',
#      'name': 'Japan',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Kern',
#      'label': 'Kern',
#      'name': 'Kern',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Korea',
#      'label': 'Korea',
#      'name': 'Korea',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Maryland',
#      'label': 'Maryland',
#      'name': 'Maryland',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Massachusetts',
#      'label': 'Massachusetts',
#      'name': 'Massachusetts',
#      'orderId': 0,
#      'selected': False},
#     {'count': 26,
#      'hidden': False,
#      'id': 'Mexico',
#      'label': 'Mexico',
#      'name': 'Mexico',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Mexico City',
#      'label': 'Mexico City',
#      'name': 'Mexico City',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Middle Rhine',
#      'label': 'Middle Rhine',
#      'name': 'Middle Rhine',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Munich',
#      'label': 'Munich',
#      'name': 'Munich',
#      'orderId': 0,
#      'selected': False},
#     {'count': 28,
#      'hidden': False,
#      'id': 'Netherlands',
#      'label': 'Netherlands',
#      'name': 'Netherlands',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'New Hampshire',
#      'label': 'New Hampshire',
#      'name': 'New Hampshire',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'New York',
#      'label': 'New York',
#      'name': 'New York',
#      'orderId': 0,
#      'selected': False},
#     {'count': 7,
#      'hidden': False,
#      'id': 'New York City',
#      'label': 'New York City',
#      'name': 'New York City',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'New Zealand',
#      'label': 'New Zealand',
#      'name': 'New Zealand',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1913,
#      'hidden': False,
#      'id': 'North and Central America',
#      'label': 'North and Central America',
#      'name': 'North and Central America',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Norway',
#      'label': 'Norway',
#      'name': 'Norway',
#      'orderId': 0,
#      'selected': False},
#     {'count': 20,
#      'hidden': False,
#      'id': 'Oceania',
#      'label': 'Oceania',
#      'name': 'Oceania',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Pakistan',
#      'label': 'Pakistan',
#      'name': 'Pakistan',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Peru',
#      'label': 'Peru',
#      'name': 'Peru',
#      'orderId': 0,
#      'selected': False},
#     {'count': 4,
#      'hidden': False,
#      'id': 'Puerto Rico',
#      'label': 'Puerto Rico',
#      'name': 'Puerto Rico',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Pumpkin Center',
#      'label': 'Pumpkin Center',
#      'name': 'Pumpkin Center',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Romania',
#      'label': 'Romania',
#      'name': 'Romania',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Rome',
#      'label': 'Rome',
#      'name': 'Rome',
#      'orderId': 0,
#      'selected': False},
#     {'count': 13,
#      'hidden': False,
#      'id': 'Russia',
#      'label': 'Russia',
#      'name': 'Russia',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'San Francisco',
#      'label': 'San Francisco',
#      'name': 'San Francisco',
#      'orderId': 0,
#      'selected': False},
#     {'count': 3,
#      'hidden': False,
#      'id': 'Santa Barbara',
#      'label': 'Santa Barbara',
#      'name': 'Santa Barbara',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Scottish',
#      'label': 'Scottish',
#      'name': 'Scottish',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Siena',
#      'label': 'Siena',
#      'name': 'Siena',
#      'orderId': 0,
#      'selected': False},
#     {'count': 17,
#      'hidden': False,
#      'id': 'South America',
#      'label': 'South America',
#      'name': 'South America',
#      'orderId': 0,
#      'selected': False},
#     {'count': 72,
#      'hidden': False,
#      'id': 'Spain',
#      'label': 'Spain',
#      'name': 'Spain',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Sweden',
#      'label': 'Sweden',
#      'name': 'Sweden',
#      'orderId': 0,
#      'selected': False},
#     {'count': 10,
#      'hidden': False,
#      'id': 'Switzerland',
#      'label': 'Switzerland',
#      'name': 'Switzerland',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1,
#      'hidden': False,
#      'id': 'Tajikistan',
#      'label': 'Tajikistan',
#      'name': 'Tajikistan',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Tuscany',
#      'label': 'Tuscany',
#      'name': 'Tuscany',
#      'orderId': 0,
#      'selected': False},
#     {'count': 97,
#      'hidden': False,
#      'id': 'United Kingdom',
#      'label': 'United Kingdom',
#      'name': 'United Kingdom',
#      'orderId': 0,
#      'selected': False},
#     {'count': 1878,
#      'hidden': False,
#      'id': 'United States',
#      'label': 'United States',
#      'name': 'United States',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Uruguay',
#      'label': 'Uruguay',
#      'name': 'Uruguay',
#      'orderId': 0,
#      'selected': False},
#     {'count': 2,
#      'hidden': False,
#      'id': 'Venezuela',
#      'label': 'Venezuela',
#      'name': 'Venezuela',
#      'orderId': 0,
#      'selected': False}]},
#   {'facets': None,
#    'filterGroupId': None,
#    'filterGroupItems': None,
#    'filterGroupLabel': None,
#    'filterGroupName': None,
#    'filterGroupType': None,
#    'id': 'era',
#    'label': 'Date / Era',
#    'name': None,
#    'values': [{'count': 1,
# ...
#    'largeImage': 'ap/web-large/ap10.64.12.jpg',
#    'medium': 'Oil on wood',
#    'regularImage': 'ap/web-additional/ap10.64.12.jpg',
#    'teaserText': '<p>Dwight William Tryon (1849–1925) </p><p>Date: 1890<br/>Accession Number: 10.64.12</p>',
#    'title': 'Moonrise at Sunset',
#    'url': '/art/collection/search/12834?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=479'},
#   {'accessionNumber': '52.174',
#    'date': '1941',
#    'description': 'Albert Eugene Gallatin (American, Villanova, Pennsylvania 1881–1952 New York)',
#    'galleryInformation': 'Not on view',
#    'image': 'https://images.metmuseum.org/CRDImages/ma/mobile-large/SF52.174.jpg',
#    'largeImage': 'ma/web-large/SF52.174.jpg',
#    'medium': 'Oil on canvas',
#    'regularImage': 'ma/web-additional/SF52.174.jpg',
#    'teaserText': '<p>Albert Eugene Gallatin (American, Villanova, Pennsylvania 1881–1952 New York) </p><p>Date: 1941<br/>Accession Number: 52.174</p>',
#    'title': 'Parallel Forms II',
#    'url': '/art/collection/search/488689?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=480'},
#   {'accessionNumber': '1971.247',
#    'date': 'ca. 1890–95',
#    'description': 'Louis Moeller (1855–1930)',
#    'galleryInformation': 'Not on view',
#    'image': 'https://images.metmuseum.org/CRDImages/ap/mobile-large/ap1971.247.jpg',
#    'largeImage': 'ap/web-large/ap1971.247.jpg',
#    'medium': 'Oil on canvas',
#    'regularImage': 'ap/web-additional/ap1971.247.jpg',
#    'teaserText': '<p>Louis Moeller (1855–1930) </p><p>Date: ca. 1890–95<br/>Accession Number: 1971.247</p>',
#    'title': 'A Discussion',
#    'url': '/art/collection/search/11585?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=481'},
#   {'accessionNumber': '50.29',
#    'date': '1948',
#    'description': 'Philip Evergood (American, New York 1901–1973 Bridgewater, Connecticut)',
#    'galleryInformation': 'Not on view',
#    'image': 'https://images.metmuseum.org/CRDImages/ma/mobile-large/SF50.29.jpg',
#    'largeImage': 'ma/web-large/SF50.29.jpg',
#    'medium': 'Oil on canvas',
#    'regularImage': 'ma/web-additional/SF50.29.jpg',
#    'teaserText': '<p>Philip Evergood (American, New York 1901–1973 Bridgewater, Connecticut) </p><p>Date: 1948<br/>Accession Number: 50.29</p>',
#    'title': 'Her World',
#    'url': '/art/collection/search/488611?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=482'},
#   {'accessionNumber': '1984.254',
#    'date': '1984',
#    'description': 'James G. Davis (American, born Springfield, Missouri, 1931)',
#    'galleryInformation': 'Not on view',
#    'image': 'https://images.metmuseum.org/CRDImages/ma/mobile-large/sf1984.254.jpg',
#    'largeImage': 'ma/web-large/sf1984.254.jpg',
#    'medium': 'Oil and silver foil on canvas',
#    'regularImage': 'ma/web-additional/sf1984.254.jpg',
#    'teaserText': '<p>James G. Davis (American, born Springfield, Missouri, 1931) </p><p>Date: 1984<br/>Accession Number: 1984.254</p>',
#    'title': 'Garage Dog',
#    'url': '/art/collection/search/483102?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=483'},
#   {'accessionNumber': '1991.50',
#    'date': '1988',
#    'description': 'Marcia Grostein (Brazilian, born 1949)',
#    'galleryInformation': 'Not on view',
#    'image': 'https://images.metmuseum.org/CRDImages/ma/mobile-large/SF1991.50.jpg',
#    'largeImage': 'ma/web-large/SF1991.50.jpg',
#    'medium': 'Oil on canvas',
#    'regularImage': 'ma/web-additional/SF1991.50.jpg',
#    'teaserText': '<p>Marcia Grostein (Brazilian, born 1949) </p><p>Date: 1988<br/>Accession Number: 1991.50</p>',
#    'title': 'The Sacred Garden of Adam',
#    'url': '/art/collection/search/633003?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=484'},
#   {'accessionNumber': '50.91',
#    'date': '1947',
#    'description': 'Henry Hobart Nichols (1869–1962)',
#    'galleryInformation': "On view at The Met Fifth Avenue in <a href='http://maps.metmuseum.org/galleries/fifth-ave/1m/774' target='_blank'>Gallery 774</a>",
#    'image': 'https://images.metmuseum.org/CRDImages/ap/mobile-large/ap50.91.jpg',
#    'largeImage': 'ap/web-large/ap50.91.jpg',
#    'medium': 'Oil on canvas',
#    'regularImage': 'ap/web-additional/ap50.91.jpg',
#    'teaserText': '<p>Henry Hobart Nichols (1869–1962) </p><p>Date: 1947<br/>Accession Number: 50.91</p>',
#    'title': 'Shifting Shadows',
#    'url': '/art/collection/search/11658?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=485'},
#   {'accessionNumber': '1985.94',
#    'date': '1983',
#    'description': 'Rodrigo Moynihan (British (born Spain), Santa Cruz de Tenerife, Canary Islands 1910–1990 London)',
#    'galleryInformation': 'Not on view',
#    'image': 'https://images.metmuseum.org/CRDImages/ma/mobile-large/DT8062.jpg',
#    'largeImage': 'ma/web-large/DT8062.jpg',
#    'medium': 'Oil on canvas',
#    'regularImage': 'ma/web-additional/DT8062.jpg',
#    'teaserText': '<p>Rodrigo Moynihan (British (born Spain), Santa Cruz de Tenerife, Canary Islands 1910–1990 London) </p><p>Date: 1983<br/>Accession Number: 1985.94</p>',
#    'title': 'Sitting Nude and Reflected Painter (Self-Portrait)',
#    'url': '/art/collection/search/484385?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=486'},
#   {'accessionNumber': '1996.209',
#    'date': '1993',
#    'description': 'Marthe Keller (American, born New York, 1948)',
#    'galleryInformation': 'Not on view',
#    'image': 'https://images.metmuseum.org/CRDImages/ma/mobile-large/1996.209.jpg',
#    'largeImage': 'ma/web-large/1996.209.jpg',
#    'medium': 'Oil, alkyd, dry pigments and wax on canvas',
#    'regularImage': 'ma/web-additional/1996.209.jpg',
#    'teaserText': '<p>Marthe Keller (American, born New York, 1948) </p><p>Date: 1993<br/>Accession Number: 1996.209</p>',
#    'title': 'Diva',
#    'url': '/art/collection/search/486705?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=487'},
#   {'accessionNumber': '1988.119.1',
#    'date': '1929',
#    'description': 'Eda Mirsky Mann (American, 1911–2012)',
#    'galleryInformation': 'Not on view',
#    'image': 'https://images.metmuseum.org/CRDImages/ma/mobile-large/1988.119.1 - color.jpg',
#    'largeImage': 'ma/web-large/1988.119.1 - color.jpg',
#    'medium': 'Oil on canvas',
#    'regularImage': 'ma/web-additional/1988.119.1 - color.jpg',
#    'teaserText': '<p>Eda Mirsky Mann (American, 1911–2012) </p><p>Date: 1929<br/>Accession Number: 1988.119.1</p>',
#    'title': 'Lee Krasner',
#    'url': '/art/collection/search/484962?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=488'},
#   {'accessionNumber': '2012.478a–j',
#    'date': '1930–31',
#    'description': 'Thomas Hart Benton (American, Neosho, Missouri 1889–1975 Kansas City, Missouri)',
#    'galleryInformation': "On view at The Met Fifth Avenue in <a href='http://maps.metmuseum.org/galleries/fifth-ave/1/909' target='_blank'>Gallery 909</a>",
#    'image': 'https://images.metmuseum.org/CRDImages/ma/mobile-large/Instruments of Power 3200.jpg',
#    'largeImage': 'ma/web-large/Instruments of Power 3200.jpg',
#    'medium': 'Ten panels: Egg tempera with oil glazing over Permalba on a gesso ground on linen mounted to wood panels with a honeycomb interior',
#    'regularImage': 'ma/web-additional/Instruments of Power 3200.jpg',
#    'teaserText': '<p>Thomas Hart Benton (American, Neosho, Missouri 1889–1975 Kansas City, Missouri) </p><p>Date: 1930–31<br/>Accession Number: 2012.478a–j</p>',
#    'title': 'America Today',
#    'url': '/art/collection/search/499559?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=489'},
#   {'accessionNumber': '59.16.4',
#    'date': '1921',
#    'description': 'Ignacio Zuloaga (Spanish, Eibar 1870–1945 Madrid)',
#    'galleryInformation': 'Not on view',
#    'image': 'https://images.metmuseum.org/CRDImages/ma/mobile-large/168274.jpg',
#    'largeImage': 'ma/web-large/168274.jpg',
#    'medium': 'Oil on canvas',
#    'regularImage': 'ma/web-additional/168274.jpg',
#    'teaserText': '<p>Ignacio Zuloaga (Spanish, Eibar 1870–1945 Madrid) </p><p>Date: 1921<br/>Accession Number: 59.16.4</p>',
#    'title': 'Mountains of Calatayud',
#    'url': '/art/collection/search/489055?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=490'},
#   {'accessionNumber': '44.160.2',
#    'date': '1944',
#    'description': 'Lee Jackson (American, New York 1909– 2002 Southampton, New York)',
#    'galleryInformation': 'Not on view',
#    'image': 'https://images.metmuseum.org/CRDImages/ma/mobile-large/SF44.160.2.jpg',
#    'largeImage': 'ma/web-large/SF44.160.2.jpg',
#    'medium': 'Oil on canvas',
#    'regularImage': 'ma/web-additional/SF44.160.2.jpg',
#    'teaserText': '<p>Lee Jackson (American, New York 1909– 2002 Southampton, New York) </p><p>Date: 1944<br/>Accession Number: 44.160.2</p>',
#    'title': 'Incident in the Parade, St. Patrick&#39;s Day',
#    'url': '/art/collection/search/488153?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=491'},
#   {'accessionNumber': '1979.299',
#    'date': 'ca. 1750',
#    'description': ' ',
#    'galleryInformation': "On view at The Met Fifth Avenue in <a href='http://maps.metmuseum.org/galleries/fifth-ave/2/717' target='_blank'>Gallery 717</a>",
#    'image': 'https://images.metmuseum.org/CRDImages/ap/mobile-large/DT9458.jpg',
#    'largeImage': 'ap/web-large/DT9458.jpg',
#    'medium': 'Oil on canvas',
#    'regularImage': 'ap/web-additional/DT9458.jpg',
#    'teaserText': '<p>Date: ca. 1750<br/>Accession Number: 1979.299</p>',
#    'title': 'The Hunting Party—New Jersey',
#    'url': '/art/collection/search/12913?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=492'},
#   {'accessionNumber': '96.24',
#    'date': '1857',
#    'description': 'Charles Loring Elliott (1812–1868)',
#    'galleryInformation': "On view at The Met Fifth Avenue in <a href='http://maps.metmuseum.org/galleries/fifth-ave/1m/774' target='_blank'>Gallery 774</a>",
#    'image': 'https://images.metmuseum.org/CRDImages/ap/mobile-large/DT214417.jpg',
#    'largeImage': 'ap/web-large/DT214417.jpg',
#    'medium': 'Oil on canvas',
#    'regularImage': 'ap/web-additional/DT214417.jpg',
#    'teaserText': '<p>Charles Loring Elliott (1812–1868) </p><p>Date: 1857<br/>Accession Number: 96.24</p>',
#    'title': 'Mathew B. Brady',
#    'url': '/art/collection/search/10850?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=493'},
#   {'accessionNumber': '1975.1.181',
#    'date': 'ca. 1898',
#    'description': 'Armand Guillaumin (French, Paris 1841–1927 Orly)',
#    'galleryInformation': 'Not on view',
#    'image': 'https://images.metmuseum.org/CRDImages/rl/mobile-large/DT3119.jpg',
#    'largeImage': 'rl/web-large/DT3119.jpg',
#    'medium': 'Oil on canvas',
#    'regularImage': 'rl/web-additional/DT3119.jpg',
#    'teaserText': '<p>Armand Guillaumin (French, Paris 1841–1927 Orly) </p><p>Date: ca. 1898<br/>Accession Number: 1975.1.181</p>',
#    'title': 'The Bouchardon Mill, Crozant',
#    'url': '/art/collection/search/459102?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=494'},
#   {'accessionNumber': '66.74.2',
#    'date': '1921',
#    'description': 'Allen Tucker (American, Brooklyn, New York 1866–1939 New York)',
#    'galleryInformation': 'Not on view',
#    'image': 'https://images.metmuseum.org/CRDImages/ap/mobile-large/ap66.74.2.jpg',
#    'largeImage': 'ap/web-large/ap66.74.2.jpg',
#    'medium': 'Oil on canvas',
#    'regularImage': 'ap/web-additional/ap66.74.2.jpg',
#    'teaserText': '<p>Allen Tucker (American, Brooklyn, New York 1866–1939 New York) </p><p>Date: 1921<br/>Accession Number: 66.74.2</p>',
#    'title': 'Interior',
#    'url': '/art/collection/search/12837?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=495'},
#   {'accessionNumber': '1994.588.1',
#    'date': '1957',
#    'description': 'Jacques Villon (French, Damville 1875–1963 Puteaux)',
#    'galleryInformation': 'Not on view',
#    'image': 'https://images.metmuseum.org/CRDImages/ma/mobile-large/264905_1994.588.1.jpg',
#    'largeImage': 'ma/web-large/264905_1994.588.1.jpg',
#    'medium': 'Oil on glassine',
#    'regularImage': 'ma/web-additional/264905_1994.588.1.jpg',
#    'teaserText': '<p>Jacques Villon (French, Damville 1875–1963 Puteaux) </p><p>Date: 1957<br/>Accession Number: 1994.588.1</p>',
#    'title': 'Palette',
#    'url': '/art/collection/search/486502?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=496'},
#   {'accessionNumber': '1975.1.159',
#    'date': '1906–7',
#    'description': 'Georges Braque (French, Argenteuil 1882–1963 Paris)',
#    'galleryInformation': "On view at The Met Fifth Avenue in <a href='http://maps.metmuseum.org/galleries/fifth-ave/1/962' target='_blank'>Gallery 962</a>",
#    'image': 'https://images.metmuseum.org/CRDImages/rl/mobile-large/DT3107.jpg',
#    'largeImage': 'rl/web-large/DT3107.jpg',
#    'medium': 'Oil on canvas',
#    'regularImage': 'rl/web-additional/DT3107.jpg',
#    'teaserText': '<p>Georges Braque (French, Argenteuil 1882–1963 Paris) </p><p>Date: 1906–7<br/>Accession Number: 1975.1.159</p>',
#    'title': 'House behind Trees',
#    'url': '/art/collection/search/459142?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=497'},
#   {'accessionNumber': '1978.453',
#    'date': '1947',
#    'description': 'Robert Goodnough (American, Cortland, New York 1917–2010 White Plains, New York)',
#    'galleryInformation': 'Not on view',
#    'image': 'https://images.metmuseum.org/CRDImages/ma/mobile-large/sf1978.453.jpg',
#    'largeImage': 'ma/web-large/sf1978.453.jpg',
#    'medium': 'Oil on paper',
#    'regularImage': 'ma/web-additional/sf1978.453.jpg',
#    'teaserText': '<p>Robert Goodnough (American, Cortland, New York 1917–2010 White Plains, New York) </p><p>Date: 1947<br/>Accession Number: 1978.453</p>',
#    'title': 'Untitled',
#    'url': '/art/collection/search/481819?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=498'},
#   {'accessionNumber': '1980.235',
#    'date': 'ca. 1963–65',
#    'description': 'Jean Isy de Botton (French, Thessalonica 1898–1978)',
#    'galleryInformation': 'Not on view',
#    'image': 'https://images.metmuseum.org/CRDImages/ma/mobile-large/sf1980.235.jpg',
#    'largeImage': 'ma/web-large/sf1980.235.jpg',
#    'medium': 'Oil on canvas',
#    'regularImage': 'ma/web-additional/sf1980.235.jpg',
#    'teaserText': '<p>Jean Isy de Botton (French, Thessalonica 1898–1978) </p><p>Date: ca. 1963–65<br/>Accession Number: 1980.235</p>',
#    'title': 'Rhythm of Flowers',
#    'url': '/art/collection/search/482067?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=499'},
#   {'accessionNumber': '67.187.164',
#    'date': '1932',
#    'description': 'John Kane (America, West Calder, Scotland 1860–1934 Pittsburg, Pennsylvania)',
#    'galleryInformation': "On view at The Met Fifth Avenue in <a href='http://maps.metmuseum.org/galleries/fifth-ave/1/911' target='_blank'>Gallery 911</a>",
#    'image': 'https://images.metmuseum.org/CRDImages/ap/mobile-large/APS507.JPG',
#    'largeImage': 'ap/web-large/APS507.JPG',
#    'medium': 'Oil on canvas',
#    'regularImage': 'ap/web-additional/APS507.JPG',
#    'teaserText': '<p>John Kane (America, West Calder, Scotland 1860–1934 Pittsburg, Pennsylvania) </p><p>Date: 1932<br/>Accession Number: 67.187.164</p>',
#    'title': 'From My Studio Window',
#    'url': '/art/collection/search/19345?sortBy=Relevance&amp;what=Oil+paintings%7cPaintings&amp;ft=*&amp;offset=400&amp;rpp=100&amp;pos=500'}],
#  'totalCollectionResults': 457152,
#  'totalResults': 3023}

# %%
url = 'http://pycoders.com/archive/'  
#This does the magic.Loads everything
r = Render(url)  
#result is a QString.
result = r.frame.toHtml()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-405048d241aa> in <module>()
#       1 url = 'http://pycoders.com/archive/'
#       2 #This does the magic.Loads everything
# ----> 3 r = Render(url)
#       4 #result is a QString.
#       5 result = r.frame.toHtml()
#
# NameError: name 'Render' is not defined

# %%
#QString should be converted to string before processed by lxml
formatted_result = str(result.toAscii())

#Next build lxml tree from formatted_result
tree = html.fromstring(formatted_result)

#Now using correct Xpath we are fetching URL of archives
archive_links = tree.xpath('//div[@class="campaign"]/a/@href')
print archive_links

# %%
body_str = resp.content.decode('utf-8')
body_str
# Out:
# '\r\n\r\n<!DOCTYPE html>\r\n<html lang="">\r\n<head>\r\n    \r\n    <title>Search the Collection | The Metropolitan Museum of Art</title>\r\n    <meta charset="UTF-8">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n        <meta name="title" content="Search the Collection" />\r\n        <meta name="keywords" content="collection" />\r\n        <meta name="description" content="Search the Metropolitan Museum&amp;#39;s Collection Online." />\r\n            <link rel="canonical" href="https://www.metmuseum.org/art/collection/search" />\r\n            <meta property="fb:admins" content="100000423552506" />\r\n            <meta property="og:image" content="http://www.metmuseum.org" />\r\n            <meta property="og:url" content="https://www.metmuseum.org/art/collection/search" />\r\n            <meta property="og:title" content="Search the Collection" />\r\n            <meta property="og:type" content="website" />\r\n            <meta property="og:site_name" content="The Metropolitan Museum of Art, i.e. The Met Museum" />\r\n            <meta property="og:description" content="Search the Metropolitan Museum&amp;#39;s Collection Online." />\r\n\r\n<!-- Google Translate -->\r\n<meta name="google-translate-customization" content="a7fb561d1c200199-4b9ad704ec9d96f4-gd48e9f4054bddd57-11"></meta>\r\n\r\n    \r\n        <script src="/js/jquery-3.3.1.min.js"></script>\r\n    <link href="/dist/css/met-fantasy-6b890169-9b4b-44a1-99de-0ca04ad954d7.css" rel="stylesheet" type="text/css" /><script src="/dist/js/met-additional-methods-331e9712-2db6-4f28-a893-8edd3b0df4d5.js" type="text/javascript"></script><script src="/dist/js/met-async-header-a960d7a0-d20a-476d-afb6-39e0aef3c0e2.js" type="text/javascript" async></script>        <script type="text/javascript" src="/content/js/pinimages.js" async></script>\r\n\r\n\r\n    \r\n    <link href="/dist/css/metprint-cf4fe22c-02da-4261-8cca-470f76e244b7.css" rel="stylesheet" type="text/css" media="print" />\r\n    <script src="/dist/js/met-header-15d1a4c1-18d9-40d0-8e99-46c9a942286a.js" type="text/javascript"></script>\r\n\r\n    \r\n    <script type="text/javascript">\r\n        window.pageData = new PageDataStore();\r\n    </script>\r\n\r\n    \r\n    <script type="application/ld+json">\r\n    </script>\r\n    \r\n   \r\n    <!-- Facebook Pixel Code -->\r\n    <script>\r\n          !function (f, b, e, v, n, t, s) {\r\n              if (f.fbq) return; n = f.fbq = function () {\r\n                  n.callMethod ?\r\n                  n.callMethod.apply(n, arguments) : n.queue.push(arguments)\r\n              }; if (!f._fbq) f._fbq = n;\r\n              n.push = n; n.loaded = !0; n.version = \'2.0\'; n.queue = []; t = b.createElement(e); t.async = !0;\r\n              t.src = v; s = b.getElementsByTagName(e)[0]; s.parentNode.insertBefore(t, s)\r\n          }(window,\r\n          document, \'script\', \'https://connect.facebook.net/en_US/fbevents.js\');\r\n\r\n          fbq(\'init\', \'1397289793845022\');\r\n          fbq(\'track\', "PageView");\r\n    </script>\r\n    <noscript>\r\n        <img height="1" width="1" style="display:none"\r\n             src="https://www.facebook.com/tr?id=1397289793845022&ev=PageView&noscript=1" />\r\n    </noscript>\r\n    <!-- End Facebook Pixel Code -->\r\n\r\n    \r\n    <script src="https://cdn.optimizely.com/js/8306101470.js"></script>\r\n\r\n    <link rel="shortcut icon" href="/content/img/presentation/icons/favicons/favicon.ico?v=3">\r\n    <link rel="apple-touch-icon" sizes="57x57" href="/content/img/presentation/icons/favicons/apple-icon-57x57.png?v=3">\r\n    <link rel="apple-touch-icon" sizes="60x60" href="/content/img/presentation/icons/favicons/apple-icon-60x60.png?v=3">\r\n    <link rel="apple-touch-icon" sizes="72x72" href="/content/img/presentation/icons/favicons/apple-icon-72x72.png?v=3">\r\n    <link rel="apple-touch-icon" sizes="76x76" href="/content/img/presentation/icons/favicons/apple-icon-76x76.png?v=3">\r\n    <li ...

# %%
sel = scrapy.Selector(text=body_str, type="html")
sel
# Out:
# <Selector xpath=None data='<html lang="">\r\n<head>\r\n    \r\n    <title'>

# %%
#grid = sel.css('figure')[0]
grid = sel.xpath('//div[re:test(@class, "grid-listing")]//figure').extract()
#want to select by class name : grid-listing

# %%
grid
# Out:
# ['<figure class="card__standard-image">\r\n        <a href="%7B%7B%20card.url%20%7D%7D"><img ng-src="{{ card.image }}" alt=""></a>\r\n    </figure>']

# %%
cards = grid.css('a')[0].xpath('string()').extract()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-fa4e633bd77b> in <module>()
# ----> 1 cards = grid.css('a')[0].xpath('string()').extract()
#
# AttributeError: 'list' object has no attribute 'css'

# %%
headers = {'User-Agent': 'UNC Journo Class'}
base_url = 'https://www.metmuseum.org/art/collection/'
url = base_url + 'search/198560?sortBy=Relevance&amp;ao=on&amp;ft=*&amp;offset=0&amp;rpp=20&amp;pos=2'
resp = requests.get(url, headers=headers)

# %%
body_str = resp.content.decode('utf-8')
body_str
# Out:
# '\r\n\r\n<!DOCTYPE html>\r\n<html lang="">\r\n<head>\r\n    \r\n    <title>Possibly by Joachim Smith | Portrait of a man | British | The Met</title>\r\n    <meta charset="UTF-8">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n        <meta name="title" content="Possibly by Joachim Smith | Portrait of a man | British | The Met" />\r\n        <meta name="keywords" content="Smith Joachim$Joachim Smith, Miniature, Wax, Frames, Sculpture, Reliefs, Europe, United Kingdom" />\r\n            <link rel="canonical" href="https://www.metmuseum.org/art/collection/search/198560" />\r\n            <meta property="fb:admins" content="100000423552506" />\r\n            <meta property="og:image" content="https://images.metmuseum.org/CRDImages/es/web-additional/DP-13721-017.jpg" />\r\n            <meta property="og:url" content="https://www.metmuseum.org/art/collection/search/198560" />\r\n            <meta property="og:title" content="Possibly by Joachim Smith | Portrait of a man | British | The Met" />\r\n            <meta property="og:type" content="website" />\r\n            <meta property="og:site_name" content="The Metropolitan Museum of Art, i.e. The Met Museum" />\r\n\r\n<!-- Google Translate -->\r\n<meta name="google-translate-customization" content="a7fb561d1c200199-4b9ad704ec9d96f4-gd48e9f4054bddd57-11"></meta>\r\n\r\n    \r\n        <script src="/js/jquery-3.3.1.min.js"></script>\r\n    <link href="/dist/css/collections-36f7b027-69a6-4f40-8393-c87103bf33dc.css" rel="stylesheet" type="text/css" />\r\n\r\n    \r\n    <link href="/dist/css/metprint-4963beb9-6c1d-45e6-8d67-a169b8d9bc47.css" rel="stylesheet" type="text/css" media="print" />\r\n    <script src="/dist/js/met-header-87c4c1a2-de05-47b4-9217-446efb22d2c2.js" type="text/javascript"></script>\r\n\r\n    \r\n    <script type="text/javascript">\r\n        window.pageData = new PageDataStore();\r\n    </script>\r\n\r\n    \r\n    <script type="application/ld+json">\r\n    </script>\r\n    \r\n   \r\n    <!-- Facebook Pixel Code -->\r\n    <script>\r\n          !function (f, b, e, v, n, t, s) {\r\n              if (f.fbq) return; n = f.fbq = function () {\r\n                  n.callMethod ?\r\n                  n.callMethod.apply(n, arguments) : n.queue.push(arguments)\r\n              }; if (!f._fbq) f._fbq = n;\r\n              n.push = n; n.loaded = !0; n.version = \'2.0\'; n.queue = []; t = b.createElement(e); t.async = !0;\r\n              t.src = v; s = b.getElementsByTagName(e)[0]; s.parentNode.insertBefore(t, s)\r\n          }(window,\r\n          document, \'script\', \'https://connect.facebook.net/en_US/fbevents.js\');\r\n\r\n          fbq(\'init\', \'1397289793845022\');\r\n          fbq(\'track\', "PageView");\r\n    </script>\r\n    <noscript>\r\n        <img height="1" width="1" style="display:none"\r\n             src="https://www.facebook.com/tr?id=1397289793845022&ev=PageView&noscript=1" />\r\n    </noscript>\r\n    <!-- End Facebook Pixel Code -->\r\n\r\n    \r\n    <script src="https://cdn.optimizely.com/js/8306101470.js"></script>\r\n\r\n    <link rel="shortcut icon" href="/content/img/presentation/icons/favicons/favicon.ico?v=3">\r\n    <link rel="apple-touch-icon" sizes="57x57" href="/content/img/presentation/icons/favicons/apple-icon-57x57.png?v=3">\r\n    <link rel="apple-touch-icon" sizes="60x60" href="/content/img/presentation/icons/favicons/apple-icon-60x60.png?v=3">\r\n    <link rel="apple-touch-icon" sizes="72x72" href="/content/img/presentation/icons/favicons/apple-icon-72x72.png?v=3">\r\n    <link rel="apple-touch-icon" sizes="76x76" href="/content/img/presentation/icons/favicons/apple-icon-76x76.png?v=3">\r\n    <link rel="apple-touch-icon" sizes="114x114" href="/content/img/presentation/icons/favicons/apple-icon-114x114.png?v=3">\r\n    <link rel="apple-touch-icon" sizes="120x120" href="/content/img/presentation/icons/favicons/apple-icon-120x120.png?v=3">\r\n    <link rel="apple-touch-icon" sizes="144x144" href="/co ...

# %%
sel = scrapy.Selector(text=body_str)
sel
# Out:
# <Selector xpath=None data='<html lang="">\r\n<head>\r\n    \r\n    <title'>

# %%
#table = sel.css('collection-details__tombstone')[0]
table = sel.css('dl')

# %%
table
# Out:
# [<Selector xpath='descendant-or-self::dl' data='<dl class="collection-details__tombstone'>,
#  <Selector xpath='descendant-or-self::dl' data='<dl class="collection-details__tombstone'>,
#  <Selector xpath='descendant-or-self::dl' data='<dl class="collection-details__tombstone'>,
#  <Selector xpath='descendant-or-self::dl' data='<dl class="collection-details__tombstone'>,
#  <Selector xpath='descendant-or-self::dl' data='<dl class="collection-details__tombstone'>,
#  <Selector xpath='descendant-or-self::dl' data='<dl class="collection-details__tombstone'>,
#  <Selector xpath='descendant-or-self::dl' data='<dl class="collection-details__tombstone'>,
#  <Selector xpath='descendant-or-self::dl' data='<dl class="collection-details__tombstone'>]

# %%
cols = table.css('dt').xpath('string()').extract()

# %%
cols
# Out:
# ['Maker:',
#  'Date:',
#  'Culture:',
#  'Medium:',
#  'Dimensions:',
#  'Classification:',
#  'Credit Line:',
#  'Accession Number:']

# %%
title = sel.css('h1').xpath('string()').extract()
title
# Out:
# ['Portrait of a man']

# %%
rows = table.css('dd').xpath('string()').extract()
rows
# Out:
# ['Possibly by Joachim Smith (active 1774)',
#  '1798',
#  'British',
#  'Colored wax; frame: wood',
#  'Framed: 12 × 10 3/4 in. (30.5 × 27.3 cm)',
#  'Sculpture-Miniature',
#  'Gift of Mrs. J. Insley Blair, 1939',
#  '39.180.4']

# %%
paintings = [] 
for r in rows:
    data = {}
    for i, d in enumerate(r.css('dd')):
        a = d.css('a')
        if a:
            t = a.xpath('text()').extract()[0]
            data['href'] = a.xpath('@href').extract()[0]
        else:
            t = d.xpath('text()').extract()[0]
        data[cols[i]] = t
    paintings.append(data)
